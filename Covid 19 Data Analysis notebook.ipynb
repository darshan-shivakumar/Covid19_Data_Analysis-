# %% [markdown]
# # COVID-19 Data Analysis using Python

# %% [markdown]
# ### Import the modules

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Importing the covid confirmed cases dataset

# %%
covid_data= pd.read_csv("covid19_Confirmed_dataset.csv")
covid_data.head()
# Out:
#   Province/State Country/Region      Lat     Long  1/22/20  1/23/20  1/24/20  \
# 0            NaN    Afghanistan  33.0000  65.0000        0        0        0
# 1            NaN        Albania  41.1533  20.1683        0        0        0
# 2            NaN        Algeria  28.0339   1.6596        0        0        0
# 3            NaN        Andorra  42.5063   1.5218        0        0        0
# 4            NaN         Angola -11.2027  17.8739        0        0        0
#
#    1/25/20  1/26/20  1/27/20  ...  4/21/20  4/22/20  4/23/20  4/24/20  \
# 0        0        0        0  ...     1092     1176     1279     1351
# 1        0        0        0  ...      609      634      663      678
# 2        0        0        0  ...     2811     2910     3007     3127
# 3        0        0        0  ...      717      723      723      731
# 4        0        0        0  ...       24       25       25       25
#
#    4/25/20  4/26/20  4/27/20  4/28/20  4/29/20  4/30/20
# ...

# %%
covid_data.shape
# Out:
# (266, 104)

# %% [markdown]
# ### Removing the useless columns

# %%
covid_data.drop(['Lat','Long'],axis=1,inplace=True)
covid_data.head()
# Out:
#   Province/State Country/Region  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  \
# 0            NaN    Afghanistan        0        0        0        0        0
# 1            NaN        Albania        0        0        0        0        0
# 2            NaN        Algeria        0        0        0        0        0
# 3            NaN        Andorra        0        0        0        0        0
# 4            NaN         Angola        0        0        0        0        0
#
#    1/27/20  1/28/20  1/29/20  ...  4/21/20  4/22/20  4/23/20  4/24/20  \
# 0        0        0        0  ...     1092     1176     1279     1351
# 1        0        0        0  ...      609      634      663      678
# 2        0        0        0  ...     2811     2910     3007     3127
# 3        0        0        0  ...      717      723      723      731
# 4        0        0        0  ...       24       25       25       25
#
#    4/25/20  4/26/20  4/27/20  4/28/20  4/29/20  4/30/20
# ...

# %%
covid_agg = covid_data.groupby("Country/Region").sum()
covid_agg.head(10)
# Out:
#                      1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# Country/Region
# Afghanistan                0        0        0        0        0        0
# Albania                    0        0        0        0        0        0
# Algeria                    0        0        0        0        0        0
# Andorra                    0        0        0        0        0        0
# Angola                     0        0        0        0        0        0
# Antigua and Barbuda        0        0        0        0        0        0
# Argentina                  0        0        0        0        0        0
# Armenia                    0        0        0        0        0        0
# Australia                  0        0        0        0        4        5
# Austria                    0        0        0        0        0        0
#
#                      1/28/20  1/29/20  1/30/20  1/31/20  ...  4/21/20  \
# Country/Region                                           ...
# ...

# %%
covid_agg.shape
# Out:
# (187, 100)

# %% [markdown]
# ## Visualizing data related to particular countries

# %%
covid_agg.loc['India']
# Out:
# 1/22/20        0
# 1/23/20        0
# 1/24/20        0
# 1/25/20        0
# 1/26/20        0
#            ...
# 4/26/20    27890
# 4/27/20    29451
# 4/28/20    31324
# 4/29/20    33062
# 4/30/20    34863
# Name: India, Length: 100, dtype: int64

# %%
# Now lets plot it as a graph

covid_agg.loc['India'].plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Now let's plot wrt Italy and spain

# %%
covid_agg.loc['India'].plot()
covid_agg.loc['China'].plot()
covid_agg.loc['Italy'].plot()
covid_agg.loc['Spain'].plot()
plt.legend()

# %% [markdown]
# ## Calculating a good measure

# %%
# Taking China as an example

covid_agg.loc['China'].plot()
# Out:
# <AxesSubplot:>

# %%
# Now let's plot for only first 3 days

covid_agg.loc['China'][:3].plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## As we can see the increase in cases each day, lets plot first derivative of curve to find the rate of maximum cases

# %%
covid_agg.loc['China'].diff().plot()
# Out:
# <AxesSubplot:>

# %%
covid_agg.loc['China'].diff().max()
# Out:
# 15136.0

# %%
# similarly for India
covid_agg.loc['India'].diff().plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Now let us calculate highest one day record for all countries

# %%
# lets make a list of all countries

countries= list(covid_agg.index)
max_inf_rate=[]
for i in countries:
    max_inf_rate.append(covid_agg.loc[i].diff().max())
    
covid_agg['Maximum_infection_rate']= max_inf_rate
covid_agg.head()
# Out:
#                 1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  \
# Country/Region
# Afghanistan           0        0        0        0        0        0        0
# Albania               0        0        0        0        0        0        0
# Algeria               0        0        0        0        0        0        0
# Andorra               0        0        0        0        0        0        0
# Angola                0        0        0        0        0        0        0
#
#                 1/29/20  1/30/20  1/31/20  ...  4/22/20  4/23/20  4/24/20  \
# Country/Region                             ...
# Afghanistan           0        0        0  ...     1176     1279     1351
# Albania               0        0        0  ...      634      663      678
# Algeria               0        0        0  ...     2910     3007     3127
# Andorra               0        0        0  ...      723      723      731
# ...

# %% [markdown]
# ## Now let's remove other columns

# %%
# we create a new dataframe using pandas 

covid19_data= pd.DataFrame(covid_agg['Maximum_infection_rate'])

# %%
covid19_data.head()
# Out:
#                 Maximum_infection_rate
# Country/Region
# Afghanistan                      232.0
# Albania                           34.0
# Algeria                          199.0
# Andorra                           43.0
# Angola                             5.0

# %% [markdown]
# # Importing the Happiness report dataset

# %%
happ_report=pd.read_csv('worldwide_happiness_report.csv')
happ_report.head(10)
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
# 5             6       Switzerland  7.480           1.452           1.526
# 6             7            Sweden  7.343           1.387           1.487
# 7             8       New Zealand  7.307           1.303           1.557
# 8             9            Canada  7.278           1.365           1.505
# 9            10           Austria  7.246           1.376           1.475
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# ...

# %% [markdown]
# ### Let's remove the unwanted columns

# %%
columns=['Overall rank','Score','Generosity','Perceptions of corruption']

happ_report.drop(columns,axis=1,inplace=True)

happ_report.head(10)
# Out:
#   Country or region  GDP per capita  Social support  Healthy life expectancy  \
# 0           Finland           1.340           1.587                    0.986
# 1           Denmark           1.383           1.573                    0.996
# 2            Norway           1.488           1.582                    1.028
# 3           Iceland           1.380           1.624                    1.026
# 4       Netherlands           1.396           1.522                    0.999
# 5       Switzerland           1.452           1.526                    1.052
# 6            Sweden           1.387           1.487                    1.009
# 7       New Zealand           1.303           1.557                    1.026
# 8            Canada           1.365           1.505                    1.039
# 9           Austria           1.376           1.475                    1.016
#
#    Freedom to make life choices
# 0                         0.596
# 1                         0.592
# ...

# %%
# Now let's make the country/region as index

happ_report.set_index('Country or region',inplace=True)

happ_report.head(10)
# Out:
#                    GDP per capita  Social support  Healthy life expectancy  \
# Country or region
# Finland                     1.340           1.587                    0.986
# Denmark                     1.383           1.573                    0.996
# Norway                      1.488           1.582                    1.028
# Iceland                     1.380           1.624                    1.026
# Netherlands                 1.396           1.522                    0.999
# Switzerland                 1.452           1.526                    1.052
# Sweden                      1.387           1.487                    1.009
# New Zealand                 1.303           1.557                    1.026
# Canada                      1.365           1.505                    1.039
# Austria                     1.376           1.475                    1.016
#
#                    Freedom to make life choices
# Country or region
# Finland                                   0.596
# ...

# %% [markdown]
# # Joining both confirmed cases and happiness report datasets.

# %%
covid19_data.head(10)
# Out:
#                      Maximum_infection_rate
# Country/Region
# Afghanistan                           232.0
# Albania                                34.0
# Algeria                               199.0
# Andorra                                43.0
# Angola                                  5.0
# Antigua and Barbuda                     6.0
# Argentina                             291.0
# Armenia                               134.0
# Australia                             497.0
# Austria                              1321.0

# %%
covid19_data.shape
# Out:
# (187, 1)

# %%
happ_report.head(10)
# Out:
#                    GDP per capita  Social support  Healthy life expectancy  \
# Country or region
# Finland                     1.340           1.587                    0.986
# Denmark                     1.383           1.573                    0.996
# Norway                      1.488           1.582                    1.028
# Iceland                     1.380           1.624                    1.026
# Netherlands                 1.396           1.522                    0.999
# Switzerland                 1.452           1.526                    1.052
# Sweden                      1.387           1.487                    1.009
# New Zealand                 1.303           1.557                    1.026
# Canada                      1.365           1.505                    1.039
# Austria                     1.376           1.475                    1.016
#
#                    Freedom to make life choices
# Country or region
# Finland                                   0.596
# ...

# %%
happ_report.shape
# Out:
# (156, 4)

# %%
# We perform the join operation using inner join since both datasets don't have same no.of rows

covid_19 = covid19_data.join(happ_report,how='inner')

covid_19.head(15)
# Out:
#              Maximum_infection_rate  GDP per capita  Social support  \
# Afghanistan                   232.0           0.350           0.517
# Albania                        34.0           0.947           0.848
# Algeria                       199.0           1.002           1.160
# Argentina                     291.0           1.092           1.432
# Armenia                       134.0           0.850           1.055
# Australia                     497.0           1.372           1.548
# Austria                      1321.0           1.376           1.475
# Azerbaijan                    105.0           1.043           1.147
# Bahrain                       301.0           1.362           1.368
# Bangladesh                    641.0           0.562           0.928
# Belarus                      1485.0           1.067           1.465
# Belgium                      2454.0           1.356           1.504
# Benin                          19.0           0.393           0.437
# ...

# %% [markdown]
# ## Correlation

# %%
# correlation gives the dependency of factors on each other

covid_19.corr()
# Out:
#                               Maximum_infection_rate  GDP per capita  \
# Maximum_infection_rate                      1.000000        0.250118
# GDP per capita                              0.250118        1.000000
# Social support                              0.191958        0.759468
# Healthy life expectancy                     0.289263        0.863062
# Freedom to make life choices                0.078196        0.394603
#
#                               Social support  Healthy life expectancy  \
# Maximum_infection_rate              0.191958                 0.289263
# GDP per capita                      0.759468                 0.863062
# Social support                      1.000000                 0.765286
# Healthy life expectancy             0.765286                 1.000000
# Freedom to make life choices        0.456246                 0.427892
#
#                               Freedom to make life choices
# Maximum_infection_rate                            0.078196
# ...

# %% [markdown]
# # Visualisation of the results

# %%
covid_19.head(50)
# Out:
#                           Maximum_infection_rate  GDP per capita  \
# Afghanistan                                232.0           0.350
# Albania                                     34.0           0.947
# Algeria                                    199.0           1.002
# Argentina                                  291.0           1.092
# Armenia                                    134.0           0.850
# Australia                                  497.0           1.372
# Austria                                   1321.0           1.376
# Azerbaijan                                 105.0           1.043
# Bahrain                                    301.0           1.362
# Bangladesh                                 641.0           0.562
# Belarus                                   1485.0           1.067
# Belgium                                   2454.0           1.356
# Benin                                       19.0           0.393
# ...

# %% [markdown]
# ## Plotting GDP vs Maximum infection rate

# %%
import warnings
warnings.simplefilter(action="ignore", category=FutureWarning)

# %%
import seaborn as sns
x=covid_19['GDP per capita']
y= covid_19['Maximum_infection_rate']
z= np.log(y)
sns.scatterplot(x,z)
# Out:
# <AxesSubplot:xlabel='GDP per capita', ylabel='Maximum_infection_rate'>

# %%
sns.regplot(x,z)
# Out:
# <AxesSubplot:xlabel='GDP per capita', ylabel='Maximum_infection_rate'>

# %% [markdown]
# ## Plotting Healthy life expectancy vs Maximum_infection_rate

# %%
x=covid_19['Healthy life expectancy']
y= covid_19['Maximum_infection_rate']
z= np.log(y)
sns.scatterplot(x,z)
# Out:
# <AxesSubplot:xlabel='Healthy life expectancy', ylabel='Maximum_infection_rate'>

# %%
sns.regplot(x,z)
# Out:
# <AxesSubplot:xlabel='Healthy life expectancy', ylabel='Maximum_infection_rate'>

# %% [markdown]
# # Conclusion
# ## From our Analysis we can conclude that Developed countries are more prone to the spread of Covid19 virus.
